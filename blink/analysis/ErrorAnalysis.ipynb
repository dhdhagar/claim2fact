# %%
# !unzip results_fulltext.zip
# Out:
# Archive:  results_fulltext.zip
#   inflating: fulltext_1nn.json
#   inflating: fulltext_in_batch.json
#   inflating: fulltext_knn.json
#   inflating: fulltext_mst.json

# %%
import json

# %%
with open('fulltext_mst.json') as f:
  results = json.load(f)

# %%
results.keys()
# Out:
# dict_keys(['n_entities', 'n_mentions', 'knn_mentions', 'accuracy', 'failure', 'success'])

# %%
results['n_mentions']
# Out:
# 5202

# %%
results['knn_mentions']
# Out:
# 2

# %%
results['accuracy']
# Out:
# '16.782006920415224 %'

# %%
success = results['success']
failure = results['failure']

# %%
success[0]
# Out:
# {'mention_gold_cui': '272',
#  'mention_gold_cui_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush',
#  'mention_id': 791407718267514880,
#  'mention_name': 'remember when person said we didnt lose a single person in libya yeah so do i hashtag url hashtag',
#  'predicted_cui': '272',
#  'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'}

# %%
len(success)
# Out:
# 873

# %%
# Check how many success and failure are Politifact or Snopes
snopes_success_count = sum([1 if 'Snopes' in x['mention_gold_cui_name'] else 0 for x in success])
snopes_failure_count = sum([1 if 'Snopes' in x['mention_gold_cui_name'] else 0 for x in failure])
politifact_success_count = sum([1 if 'PolitiFact' in x['mention_gold_cui_name'] else 0 for x in success])
politifact_failure_count = sum([1 if 'PolitiFact' in x['mention_gold_cui_name'] else 0 for x in failure])

# %%
print("Snopes Success Rate: %.3f" % (snopes_success_count/(snopes_success_count+snopes_failure_count)))
print("PolitiFact Success Rate: %.3f" % (politifact_success_count/(politifact_success_count+politifact_failure_count)))
# Out:
# Snopes Success Rate: 0.144
# PolitiFact Success Rate: 0.139

# %%
success_cuis = list(set([x['mention_gold_cui'] for x in success]))
total_cuis = list(set([x['mention_gold_cui'] for x in success])) + list(set([x['mention_gold_cui'] for x in failure]))
print("No. of unique CUIs succesfully predicted: %d" % len(success_cuis))
print("Total no. of unique CUIs: %d" % len(total_cuis))
# Out:
# No. of unique CUIs succesfully predicted: 343
# Total no. of unique CUIs: 1576

# %%
success_titles = list(set([x['mention_gold_cui_name'] for x in success]))
failure_titles = list(set([x['mention_gold_cui_name'] for x in failure]))
failure_mentions = [x['mention_name'] for x in failure]
success_mentions = [x['mention_name'] for x in success]

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize.casual import TweetTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
nltk.download('wordnet')
wnl = WordNetLemmatizer()
tokenizer = TweetTokenizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
success_mentions_lemmatized = [" ".join([wnl.lemmatize(x) for x in tokenizer.tokenize(y)]) for y in success_mentions]
failure_mentions_lemmatized = [" ".join([wnl.lemmatize(x) for x in tokenizer.tokenize(y)]) for y in failure_mentions]

# %%
vectorizer = CountVectorizer(stop_words='english')
success_features = vectorizer.fit_transform(success_mentions_lemmatized)
failure_features = vectorizer.fit_transform(failure_mentions_lemmatized)

# %%
topic_model = LatentDirichletAllocation()
# Out:
# <WordListCorpusReader in '.../corpora/stopwords' (not loaded yet)>

# %%
success[20:50]
# Out:
# [{'mention_gold_cui': '279',
#   'mention_gold_cui_name': 'PolitiFact Did Obama administration approve bump stocks',
#   'mention_id': 966694930268667904,
#   'mention_name': 'user he listened to them and announced he wats to ban bump stocks that person made legal up the age to own a rifle to number and stronger background checks more security at schools what have libs done nothing',
#   'predicted_cui': '279',
#   'predicted_name': 'PolitiFact Did Obama administration approve bump stocks'},
#  {'mention_gold_cui': '279',
#   'mention_gold_cui_name': 'PolitiFact Did Obama administration approve bump stocks',
#   'mention_id': 967166231588540416,
#   'mention_name': 'of course we should ban bump stocks it should have been done a long time ago governor of ohio user on hashtag url',
#   'predicted_cui': '279',
#   'predicted_name': 'PolitiFact Did Obama administration approve bump stocks'},
#  {'mention_gold_cui': '279',
#   'mention_gold_cui_name': 'PolitiFact Did Obama administration approve bump stocks',
#   'mention_id': 977370087383552000,
#   'mention_name': 'this is a bold faced lie obama administration never legalized bump stocks obama issued executive orders creating stricter controls person rolled back all of them but could not legally restrict non mechanical bump stocks without new laws republicans in congress refused url',
#   'predicted_cui': '279',
#   'predicted_name': 'PolitiFact Did Obama administration approve bump stocks'},
#  {'mention_gold_cui': '279',
#   'mention_gold_cui_name': 'PolitiFact Did Obama administration approve bump stocks',
#   'mention_id': 963926773195997184,
#   'mention_name': 'remember when a bipartisan coalition of lawmakers said they would ban bump stocks after las vegas and fix the instant background check system after texas neither happened',
#   'predicted_cui': '279',
#   'predicted_name': 'PolitiFact Did Obama administration approve bump stocks'},
#  {'mention_gold_cui': '279',
#   'mention_gold_cui_name': 'PolitiFact Did Obama administration approve bump stocks',
#   'mention_id': 927561576823042048,
#   'mention_name': 'user and under obama admin bunt stocks were legalized soooo',
#   'predicted_cui': '279',
#   'predicted_name': 'PolitiFact Did Obama administration approve bump stocks'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 832472451002937344,
#   'mention_name': 'user well the ny times is fake but the wsj i dunno url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 823045497271091200,
#   'mention_name': 'hashtag with number different headlines same paper same date different markets bias much user is right about hashtag hashtag url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 800322949907615744,
#   'mention_name': 'while person faux media claim normal folks push fake news look wsj same date but different markets d ifferent headline url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 771746655032840192,
#   'mention_name': 'hashtag same paper same day same article different areas d ifferent title hashtag hashtag url via user',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 824261663918555136,
#   'mention_name': 'user wow with number different headlines in different markets is right about hashtag fakenews url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 805714752559259648,
#   'mention_name': 'user would you be ok if the times did similar in the uk say to readers in the north and south surely number headline is misleading',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 772513353025675264,
#   'mention_name': 'same paper same date different headlines number different markets the media playing politics hashtag user url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 832610943867695104,
#   'mention_name': 'user and here is an example of media reader manipulation at its best number different headlines same topic same day by hashtag hashtag act url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '280',
#   'mention_gold_cui_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom',
#   'mention_id': 805269903246770176,
#   'mention_name': 'user please url this its been going around for a while false',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '285',
#   'mention_gold_cui_name': 'Is This a Trump Tower Billboard in Mumbai Snopescom',
#   'mention_id': 815735672124375040,
#   'mention_name': 'some art type person needs to write an analysis on the weird back and forth over whether that person tower mumbai poverty pic was real',
#   'predicted_cui': '285',
#   'predicted_name': 'Is This a Trump Tower Billboard in Mumbai Snopescom'},
#  {'mention_gold_cui': '290',
#   'mention_gold_cui_name': 'PolitiFact Trump has signed more bills in 100 days than any president since Truman Spicer says',
#   'mention_id': 943508944110145536,
#   'mention_name': 'user you mean how the gop controls all number branches of government and still wasnt able to pass a single bill until now number',
#   'predicted_cui': '290',
#   'predicted_name': 'PolitiFact Trump has signed more bills in 100 days than any president since Truman Spicer says'},
#  {'mention_gold_cui': '290',
#   'mention_gold_cui_name': 'PolitiFact Trump has signed more bills in 100 days than any president since Truman Spicer says',
#   'mention_id': 879024907992125440,
#   'mention_name': 'user also she asked about legislation being passed as the only bills passed at this point concern renaming post offices she wins this debate',
#   'predicted_cui': '290',
#   'predicted_name': 'PolitiFact Trump has signed more bills in 100 days than any president since Truman Spicer says'},
#  {'mention_gold_cui': '295',
#   'mention_gold_cui_name': 'PolitiFact Yes Donald Trump has been linked to the mob',
#   'mention_id': 771334744323698688,
#   'mention_name': 'im not the number voting for the mafia of american politics hashtag money laundering racketeering bribery paytoplay user',
#   'predicted_cui': '295',
#   'predicted_name': 'PolitiFact Yes Donald Trump has been linked to the mob'},
#  {'mention_gold_cui': '303',
#   'mention_gold_cui_name': 'PolitiFact Bernie Sanders was the roll call amendment king from 1995 to 2007',
#   'mention_id': 922120803465990144,
#   'mention_name': 'user name number of those amendments off the top of your head thanks for reminding us he rides others bills like he rides others peoples party',
#   'predicted_cui': '303',
#   'predicted_name': 'PolitiFact Bernie Sanders was the roll call amendment king from 1995 to 2007'},
#  {'mention_gold_cui': '303',
#   'mention_gold_cui_name': 'PolitiFact Bernie Sanders was the roll call amendment king from 1995 to 2007',
#   'mention_id': 832751175447490560,
#   'mention_name': 'user the world where he sits in cong does nothing for yrs then suddenly wants to be leader of a party he doesnt belong to',
#   'predicted_cui': '303',
#   'predicted_name': 'PolitiFact Bernie Sanders was the roll call amendment king from 1995 to 2007'},
#  {'mention_gold_cui': '303',
#   'mention_gold_cui_name': 'PolitiFact Bernie Sanders was the roll call amendment king from 1995 to 2007',
#   'mention_id': 735867616275890176,
#   'mention_name': 'bernie likes to dictate he doesnt like to negotiate but negotiating is the key to getting things done in congress url',
#   'predicted_cui': '303',
#   'predicted_name': 'PolitiFact Bernie Sanders was the roll call amendment king from 1995 to 2007'},
#  {'mention_gold_cui': '151',
#   'mention_gold_cui_name': 'FACT CHECK Does President Trumps Golf Course Feature a Civil War Monument to a Fictional Battle',
#   'mention_id': 887097044137070592,
#   'mention_name': 'citing security concerns the coast guard will block access to parts of the potomac when trumps at his va golf club url',
#   'predicted_cui': '151',
#   'predicted_name': 'FACT CHECK Does President Trumps Golf Course Feature a Civil War Monument to a Fictional Battle'},
#  {'mention_gold_cui': '311',
#   'mention_gold_cui_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan',
#   'mention_id': 940612746370043904,
#   'mention_name': 'user your whole premise is false no way does he win number of all counties and lose by number votes you must have gone to person u he has never gone above the number in approval and has no mandate for anything',
#   'predicted_cui': '311',
#   'predicted_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan'},
#  {'mention_gold_cui': '311',
#   'mention_gold_cui_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan',
#   'mention_id': 822544464891838464,
#   'mention_name': 'as person becomes president a reminder of just how many votes he lost to person by url url',
#   'predicted_cui': '311',
#   'predicted_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan'},
#  {'mention_gold_cui': '311',
#   'mention_gold_cui_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan',
#   'mention_id': 814140283680071680,
#   'mention_name': 'user hahaha obama approval number person approval number lost the popular vote by number number only number of us voted for him hashtag',
#   'predicted_cui': '311',
#   'predicted_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan'},
#  {'mention_gold_cui': '311',
#   'mention_gold_cui_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan',
#   'mention_id': 811386889865490432,
#   'mention_name': 'user the left only wants to get rid of the electoralcollege this election because they lost it has nothing to do w race',
#   'predicted_cui': '311',
#   'predicted_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan'},
#  {'mention_gold_cui': '311',
#   'mention_gold_cui_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan',
#   'mention_id': 807431459405434880,
#   'mention_name': 'user number won number to hillarys number counties',
#   'predicted_cui': '311',
#   'predicted_name': 'PolitiFact Mike Pence says Donald Trump won most counties by a Republican since Ronald Reagan'},
#  {'mention_gold_cui': '315',
#   'mention_gold_cui_name': 'Was Neil Gorsuch Unanimously Confirmed in 2006 Snopescom',
#   'mention_id': 847916305126764544,
#   'mention_name': 'in number the senate unanimously confirmed user by voice vote to the data circuit court of appeals hashtag hashtag number',
#   'predicted_cui': '315',
#   'predicted_name': 'Was Neil Gorsuch Unanimously Confirmed in 2006 Snopescom'},
#  {'mention_gold_cui': '322',
#   'mention_gold_cui_name': 'PolitiFact TRUE California has the nations highest poverty rate when factoring in costofliving',
#   'mention_id': 953404406090911744,
#   'mention_name': 'user the state with the highest poverty rate is mississippi followed by new mexico louisiana alabama kentucky and arkansas guess what all these states have in common',
#   'predicted_cui': '322',
#   'predicted_name': 'PolitiFact TRUE California has the nations highest poverty rate when factoring in costofliving'},
#  {'mention_gold_cui': '322',
#   'mention_gold_cui_name': 'PolitiFact TRUE California has the nations highest poverty rate when factoring in costofliving',
#   'mention_id': 953126964059140096,
#   'mention_name': 'fox news person person asks why california is the poorest state its umm its not url',
#   'predicted_cui': '322',
#   'predicted_name': 'PolitiFact TRUE California has the nations highest poverty rate when factoring in costofliving'}]

# %%
failure[20:50]
# Out:
# [{'mention_gold_cui': '2816',
#   'mention_gold_cui_name': 'FACT CHECK Maxine Waters Fears a Trumpled War After Nuclear Attack by North Korea',
#   'mention_id': 923574207304404992,
#   'mention_name': 'user taking things out of context dhe fears nk nuking america she is then saying in a way its person who is going number make that happen',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '155',
#   'mention_gold_cui_name': 'FACT CHECK Hillary Clinton Gave 20 Percent of United States Uranium to Russia in Exchange for Clinton Foundation Donations',
#   'mention_id': 986961901245657088,
#   'mention_name': 'i love when people say person had no scandals what do they call fast and furious uranium number benghazi irs targeting nsa spying these scandals are real scandals unlike washed up porn stars looking to get rich off of falsely accusing president person',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '1518',
#   'mention_gold_cui_name': 'PolitiFact Mike Pences inaccurate claim about Clintons Benghazi role and response',
#   'mention_id': 794109314797420544,
#   'mention_name': 'user person got flaws in his character but hes not responsible for number american deaths in benghazi emails security compromised',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '1047',
#   'mention_gold_cui_name': 'PolitiFact Did Hillary Clinton start the Obama birther movement',
#   'mention_id': 932309842924097536,
#   'mention_name': 'user actually i didnt want her in jail until after benghazi i never have liked her btw wasnt she the one that used the birther claim against person in number',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '2940',
#   'mention_gold_cui_name': 'PolitiFact Donald Trump wildly exaggerates Amb Christopher Stevens requests for extra Benghazi security',
#   'mention_id': 790905079612186624,
#   'mention_name': 'user they were personal tax returns they were number calls for help in benghazi',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '2313',
#   'mention_gold_cui_name': 'PolitiFact Viral post exaggerates GOP senators bill on embassy move',
#   'mention_id': 839873044847931392,
#   'mention_name': 'user state dept sold uranium not hillarys decision benghazi is person fault number reducing number security url',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '1236',
#   'mention_gold_cui_name': 'Did Hillary Clinton Leak a Classified FourMinute Nuclear Response Window Snopescom',
#   'mention_id': 951242254248808448,
#   'mention_name': 'user she also revealed a national secret during a debate as a military member i would be in prison for saying what she said to an individual who didnt need to know and she told the world there is a double standard for her',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '1100',
#   'mention_gold_cui_name': 'PolitiFact Unfit to serve Congressman isnt even real',
#   'mention_id': 984968031129559040,
#   'mention_name': 'user these hashtag need to be limited sir we dont want to create another libya',
#   'predicted_cui': '272',
#   'predicted_name': 'PolitiFact Prior to Benghazi were there 13 attacks on embassies and 60 deaths under President George W Bush'},
#  {'mention_gold_cui': '1502',
#   'mention_gold_cui_name': 'PolitiFact Sally Kohn White men account for 69 percent of those arrested for violent crimes',
#   'mention_id': 800770952913158144,
#   'mention_name': 'user thats number yr old study homicide number fbi stats well over number violent crimes white of number number white number black',
#   'predicted_cui': '274',
#   'predicted_name': 'PolitiFact Juan Williams No 1 cause of death for AfricanAmerican males 1534 is murder'},
#  {'mention_gold_cui': '1201',
#   'mention_gold_cui_name': 'PolitiFact Trumps Pants on Fire tweet that blacks killed 81 of white homicide victims',
#   'mention_id': 876529196213964800,
#   'mention_name': 'user you fail to acknowledge black on black crime where number of black homicides are committed by other blacks',
#   'predicted_cui': '274',
#   'predicted_name': 'PolitiFact Juan Williams No 1 cause of death for AfricanAmerican males 1534 is murder'},
#  {'mention_gold_cui': '1085',
#   'mention_gold_cui_name': 'PolitiFact Did Margaret Sanger believe AfricanAmericans should be eliminated',
#   'mention_id': 847231548868837376,
#   'mention_name': 'user pp founder person was a racist kk member today more blacks are killed in abortions than aids cancer violent crime combined sad',
#   'predicted_cui': '274',
#   'predicted_name': 'PolitiFact Juan Williams No 1 cause of death for AfricanAmerican males 1534 is murder'},
#  {'mention_gold_cui': '1502',
#   'mention_gold_cui_name': 'PolitiFact Sally Kohn White men account for 69 percent of those arrested for violent crimes',
#   'mention_id': 799303779900239872,
#   'mention_name': 'im a white male white males account for the majority of violent crimes in the u s why not hashtag',
#   'predicted_cui': '274',
#   'predicted_name': 'PolitiFact Juan Williams No 1 cause of death for AfricanAmerican males 1534 is murder'},
#  {'mention_gold_cui': '3468',
#   'mention_gold_cui_name': 'PolitiFact Death rates for white men up 20 percent GOP strategist says',
#   'mention_id': 899394046673784832,
#   'mention_name': 'new death rates for white men up number percent gop strategist says url url',
#   'predicted_cui': '274',
#   'predicted_name': 'PolitiFact Juan Williams No 1 cause of death for AfricanAmerican males 1534 is murder'},
#  {'mention_gold_cui': '276',
#   'mention_gold_cui_name': 'Did Obama Suggest More Flexibility Toward Russia After the 2012 Election Snopescom',
#   'mention_id': 835870864025530368,
#   'mention_name': 'rt if youre number of the number of americans who want congress to investigate the person campaigns contact with russia url',
#   'predicted_cui': '275',
#   'predicted_name': 'PolitiFact Hillary Clinton blames highup Russians for WikiLeaks releases'},
#  {'mention_gold_cui': '1085',
#   'mention_gold_cui_name': 'PolitiFact Did Margaret Sanger believe AfricanAmericans should be eliminated',
#   'mention_id': 898202220751192064,
#   'mention_name': 'i dunno i do look forward to learning the whole story of your involvement with russian spy person person url',
#   'predicted_cui': '275',
#   'predicted_name': 'PolitiFact Hillary Clinton blames highup Russians for WikiLeaks releases'},
#  {'mention_gold_cui': '155',
#   'mention_gold_cui_name': 'FACT CHECK Hillary Clinton Gave 20 Percent of United States Uranium to Russia in Exchange for Clinton Foundation Donations',
#   'mention_id': 920463111211175936,
#   'mention_name': 'next user and join me with more on the bombshell russia report hashtag',
#   'predicted_cui': '275',
#   'predicted_name': 'PolitiFact Hillary Clinton blames highup Russians for WikiLeaks releases'},
#  {'mention_gold_cui': '1863',
#   'mention_gold_cui_name': 'Was Donald Trump Accused of Sexual Assault Prior to the 2016 Election',
#   'mention_id': 942267357606612992,
#   'mention_name': 'user didnt person ask wikileaks russia to illegally find clintons emails white house looks stupid for even saying this and fox fake news looks even dumber for doing this story the sexual misconduct and conspiracy network strikes again hashtag losers',
#   'predicted_cui': '275',
#   'predicted_name': 'PolitiFact Hillary Clinton blames highup Russians for WikiLeaks releases'},
#  {'mention_gold_cui': '1153',
#   'mention_gold_cui_name': 'Newsweek Proves That WikiLeaks Is Leaking Phony Hillary Clinton Emails Snopescom',
#   'mention_id': 786370568211824640,
#   'mention_name': 'user why is nothing being done to close down wikileaks russians have so done to us media sites like newsweek',
#   'predicted_cui': '275',
#   'predicted_name': 'PolitiFact Hillary Clinton blames highup Russians for WikiLeaks releases'},
#  {'mention_gold_cui': '1100',
#   'mention_gold_cui_name': 'PolitiFact Unfit to serve Congressman isnt even real',
#   'mention_id': 786997170884997120,
#   'mention_name': 'breaking clinton foundation foreign donors expected benefits in return for gifts number url',
#   'predicted_cui': '278',
#   'predicted_name': 'PolitiFact Yes Donald Trump donated 100000 to the Clinton Foundation'},
#  {'mention_gold_cui': '204',
#   'mention_gold_cui_name': 'Is the Owner of Jimmy Johns a BigGame Hunter Snopescom',
#   'mention_id': 859457206877642752,
#   'mention_name': 'hashtag to buy number subs at participating person person locations today from number number m',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '357',
#   'mention_gold_cui_name': 'PolitiFact Harry Reid says unlike the GOP Senate Democrats never held up a Supreme Court nomination',
#   'mention_id': 848925271533211648,
#   'mention_name': 'user that is number false research the topic before commenting or stop making things up hashtag',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '26',
#   'mention_gold_cui_name': 'CNN and MSNBC in Ratings Freefall Fox Soundly Beating Both Combined Snopescom',
#   'mention_id': 832876098664939520,
#   'mention_name': 'imbicil user is stronger than ever its the worlds leading news source hold your breath on that number please url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '285',
#   'mention_gold_cui_name': 'Is This a Trump Tower Billboard in Mumbai Snopescom',
#   'mention_id': 816098415314608128,
#   'mention_name': 'user well then it should win some kind of award for cruel irony or something',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '235',
#   'mention_gold_cui_name': 'Russian Billboard Features Trump and Putin Snopescom',
#   'mention_id': 803348714299551744,
#   'mention_name': 'user check this out too its not fake either fact checked via snopes url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '21',
#   'mention_gold_cui_name': 'Bernie Sanders 1972 Essay on Rape Snopescom',
#   'mention_id': 935067465511571456,
#   'mention_name': 'user woah really you have a source hashtag',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '747',
#   'mention_gold_cui_name': 'Were Hurricane Katrina Looting Photographs Captioned Differently Based on Race Snopescom',
#   'mention_id': 902914601322512384,
#   'mention_name': 'user right back atcha this is fake',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '276',
#   'mention_gold_cui_name': 'Did Obama Suggest More Flexibility Toward Russia After the 2012 Election Snopescom',
#   'mention_id': 836577598683557888,
#   'mention_name': 'user by a more than number to number margin americans want an investigation of trumprussia scandal url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '302',
#   'mention_gold_cui_name': 'PolitiFact Conservative group claims Hillary Clintons foundation took millions from foreign governments',
#   'mention_id': 748972690455695360,
#   'mention_name': 'user number number can buy a lot of influence government for sale url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '295',
#   'mention_gold_cui_name': 'PolitiFact Yes Donald Trump has been linked to the mob',
#   'mention_id': 794767328420319232,
#   'mention_name': 'user stop lying hashtag hashtag get your facts straight and report real new',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'},
#  {'mention_gold_cui': '624',
#   'mention_gold_cui_name': 'Producers of Hamilton Issued NonWhite Casting Call Snopescom',
#   'mention_id': 801048127306432512,
#   'mention_name': 'good morning its number a m in the east and were on user live with your top stories url',
#   'predicted_cui': '280',
#   'predicted_name': 'Two Editions of Wall Street Journal Bear Opposite Headlines About Trump Snopescom'}]

# %%
from collections import Counter

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
success_titles = [x['mention_gold_cui_name'] for x in success]
c = Counter(success_titles)

# %%
c.most_common(10)
# Out:
# [('FACT CHECK Hillary Clinton Gave 20 Percent of United States Uranium to Russia in Exchange for Clinton Foundation Donations',
#   165),
#  ('PolitiFact David Hogg not at school during shooting Bloggers spread misinformation',
#   27),
#  ('FACT CHECK Did Democrats Refuse to Stand for a Navy SEALs Widow', 20),
#  ('Are Donald Trumps Make America Great Again Caps Made in China Snopescom',
#   15),
#  ('PolitiFact Factchecking Donald Trumps claim Hillary Clinton started Obama birther movement',
#   15),
#  ('PolitiFact Mostly False 18 US school shootings so far in 2018 and 18 in rest of the world over past 20 years',
#   13),
#  ('PolitiFact No the 9th Circuit isnt the most overturned court in the country as Hannity says',
#   11),
#  ('PolitiFact Fake news posts blame Puerto Ricos truck drivers for refusing to ship relief supplies',
#   11),
#  ('Was the Texas Church Shooter an Antifa Member Who Vowed to Start Civil War Snopescom',
#   10),
#  ('No American Flags Present at the Democratic National Convention Snopescom',
#   10)]

# %%
failure_titles = [x['mention_gold_cui_name'] for x in failure]
c = Counter(failure_titles)

# %%
c.most_common(10)
# Out:
# [('FACT CHECK Hillary Clinton Gave 20 Percent of United States Uranium to Russia in Exchange for Clinton Foundation Donations',
#   195),
#  ('Hillary Clinton Kissed by Former Klan Member Snopescom', 73),
#  ('PolitiFact Did Hillary Clinton start the Obama birther movement', 68),
#  ('Is Green Party Candidate Jill Stein AntiVaccine Snopescom', 65),
#  ('Donald Trump Condoned Flag Burning Snopescom', 50),
#  ('Did Hillary Clinton Say Democratic Voters Are Stupid Snopescom', 45),
#  ('PolitiFact Why comparing Trumps and Obamas immigration restrictions is flawed',
#   40),
#  ('PolitiFact Unfit to serve Congressman isnt even real', 39),
#  ('Obama Encouraged Illegal Aliens to Vote Snopescom', 38),
#  ('PolitiFact In a nuclear claim Donald Trump says Hillary Clinton gave up onefifth of US uranium to Russia',
#   35)]

# %%
total_titles = success_titles + failure_titles
total_counts = Counter(total_titles)

# %%
new_dict = {k:c[k]/total_counts[k] for k in c.keys() if k in total_counts}

# %%
len(c.keys())
# Out:
# 343

# %%
len(total_counts.keys())
# Out:
# 1376

# %%
often_correct = [x[0] for x in sorted(new_dict.items(), key=lambda item: item[1], reverse=True) if x[1] > 0.5]

# %%
rarely_correct = [x[0] for x in sorted(new_dict.items(), key=lambda item: item[1], reverse=False) if x[1] < 0.3]

# %%
never_correct = [x[0] for x in total_counts.items() if x[0] not in c.keys()]

# %%
len(never_correct)
# Out:
# 1033

# %%
import spacy
nlp = spacy.load("en_core_web_sm", disable=["tok2vec", "tagger", "parser", "attribute_ruler", "lemmatizer"])

# %%
often_correct_titles = " ".join(often_correct)

# %%
doc_correct = nlp(often_correct_titles)

# %%
entities = []
for ent in doc.ents:
  entities.extend(ent.text.lower().split(' '))

# %%
success_entities = Counter(entities)

# %%
num_entities = sum(success_entities.values())

# %%
for key in success_entities:
  success_entities[key] /= num_entities

# %%
success_entities.most_common(20)
# Out:
# [('trump', 0.04128440366972477),
#  ('snopescom', 0.034403669724770644),
#  ('donald', 0.02981651376146789),
#  ('politifact', 0.027522935779816515),
#  ('the', 0.027522935779816515),
#  ('trumps', 0.013761467889908258),
#  ('us', 0.013761467889908258),
#  ('a', 0.011467889908256881),
#  ('hillary', 0.011467889908256881),
#  ('clinton', 0.011467889908256881),
#  ('of', 0.009174311926605505),
#  ('false', 0.009174311926605505),
#  ('white', 0.009174311926605505),
#  ('obama', 0.006880733944954129),
#  ('fact', 0.006880733944954129),
#  ('iran', 0.006880733944954129),
#  ('first', 0.006880733944954129),
#  ('united', 0.006880733944954129),
#  ('house', 0.006880733944954129),
#  ('china', 0.006880733944954129)]

# %%
never_correct_titles = " ".join(never_correct)
doc = nlp(never_correct_titles)
entities = []
for ent in doc.ents:
  entities.extend(ent.text.lower().split(' '))

# %%
failure_entities = Counter(entities)

# %%
num_entities = sum(failure_entities.values())

# %%
for key in failure_entities:
  failure_entities[key] /= num_entities

# %%
failure_entities.most_common(20)
# Out:
# [('politifact', 0.04521845401772075),
#  ('trump', 0.041857622975863124),
#  ('clinton', 0.03635808127100519),
#  ('donald', 0.03299725022914757),
#  ('snopescom', 0.03238619003971891),
#  ('hillary', 0.026886648334860985),
#  ('the', 0.026886648334860985),
#  ('trumps', 0.012832263978001834),
#  ('obama', 0.011304613504430187),
#  ('us', 0.010388023220287198),
#  ('a', 0.008860372746715552),
#  ('check', 0.007332722273143905),
#  ('sanders', 0.006721662083715246),
#  ('fact', 0.0058050717995722576),
#  ('bernie', 0.0058050717995722576),
#  ('democrats', 0.005499541704857928),
#  ('of', 0.005499541704857928),
#  ('gop', 0.00488848151542927),
#  ('john', 0.00458295142071494),
#  ('million', 0.00458295142071494)]

# %%
with open('fulltext_in_batch.json') as f:
  results = json.load(f)

# %%
predicted_cui = [x['predicted_cui'] for x in results['failure']] + [x['predicted_cui'] for x in results['success']]

# %%
Counter(predicted_cui).most_common(30)
# Out:
# [('1163', 119),
#  ('155', 88),
#  ('2885', 43),
#  ('1064', 34),
#  ('123', 31),
#  ('2118', 28),
#  ('2600', 28),
#  ('1074', 28),
#  ('1040', 25),
#  ('2822', 24),
#  ('1047', 23),
#  ('1090', 22),
#  ('44', 21),
#  ('3008', 19),
#  ('2594', 18),
#  ('2922', 18),
#  ('3163', 18),
#  ('168', 17),
#  ('57', 17),
#  ('23', 17),
#  ('1182', 17),
#  ('1592', 17),
#  ('1207', 16),
#  ('1304', 16),
#  ('1479', 16),
#  ('93', 15),
#  ('1244', 15),
#  ('1268', 15),
#  ('1449', 15),
#  ('3391', 15)]

# %%
predicted_cui = [x['predicted_cui'] for x in failure] + [x['predicted_cui'] for x in success]

# %%
Counter(predicted_cui).most_common(30)
# Out:
# [('155', 196),
#  ('1308', 164),
#  ('1545', 136),
#  ('1064', 127),
#  ('235', 102),
#  ('2015', 96),
#  ('365', 82),
#  ('1280', 82),
#  ('3398', 79),
#  ('280', 75),
#  ('2487', 73),
#  ('1557', 66),
#  ('311', 62),
#  ('1527', 61),
#  ('1719', 59),
#  ('1779', 59),
#  ('2882', 59),
#  ('1162', 56),
#  ('1268', 56),
#  ('1114', 54),
#  ('2885', 54),
#  ('1215', 50),
#  ('2428', 50),
#  ('746', 46),
#  ('1040', 46),
#  ('1157', 46),
#  ('1922', 45),
#  ('1269', 43),
#  ('1352', 43),
#  ('2146', 43)]

# %%
doc_correct = nlp(often_correct_titles)
doc_incorrect = nlp(never_correct_titles)

# %%
success_mentions_lemmatized = " ".join([" ".join([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(y)]) for y in success_mentions])
failure_mentions_lemmatized = " ".join([" ".join([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(y)]) for y in failure_mentions])

# %%
success_titles_lemmatized = " ".join([" ".join([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(y)]) for y in success_titles])
failure_titles_lemmatized = " ".join([" ".join([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(y)]) for y in failure_titles])

# %%
word_overlaps = []
for x in success:
  mention = x['mention_name']
  fact_title = x['mention_gold_cui_name']
  mention_lemmatized = set([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(mention)])
  fact_title_lemmatized = set([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(fact_title)])
  word_overlap = len(mention_lemmatized.intersection(fact_title_lemmatized))/len(mention_lemmatized.union(fact_title_lemmatized))
  word_overlaps.append(word_overlap)

# %%
word_overlaps_failure = []
for x in failure:
  mention = x['mention_name']
  fact_title = x['mention_gold_cui_name']
  mention_lemmatized = set([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(mention)])
  fact_title_lemmatized = set([wnl.lemmatize(x).lower() for x in tokenizer.tokenize(fact_title)])
  word_overlap = len(mention_lemmatized.intersection(fact_title_lemmatized))/len(mention_lemmatized.union(fact_title_lemmatized))
  word_overlaps_failure.append(word_overlap)

# %%
sum(word_overlaps)/len(word_overlaps)
# Out:
# 0.12509481152426433

# %%
sum(word_overlaps_failure)/len(word_overlaps_failure)
# Out:
# 0.04257807016520341

# %%
doc_success = nlp(success_mentions_lemmatized)
doc_failure = nlp(failure_mentions_lemmatized)

# %%
len(doc_success.ents)/len(doc_success)
# Out:
# 0.05809956757955428

# %%
len(doc_failure.ents)/len(doc_failure)
# Out:
# 0.036761195454979474

# %%
import pandas as pd

# %%
df = pd.DataFrame.from_dict(failure)

# %%
pd.set_option('display.max_colwidth', None)

# %%
pd.set_option('display.max_rows', None)

# %%
df.iloc[[1051,3224,1031,200,1547,899], :]
# Out:
#               mention_id  ... predicted_cui
# 1051  773677160322117632  ...          1064
# 3224  843948028050509824  ...          2104
# 1031  835956212076249088  ...          1064
# 200   837051377868124160  ...           311
# 1547  855905954407120896  ...          1269
# 899   845913265515352064  ...           155
#
# [6 rows x 6 columns]

# %%
df.sample(frac=0.3)[['mention_gold_cui_name', 'predicted_name']]
# Out:
#                                                                                                            mention_gold_cui_name                                                                                                                predicted_name
# 3728                                          FACT CHECK Did 58 Scientific Papers Published in 2017 Say Global Warming is a Myth                                   FACT CHECK PeerReviewed Study Proves All Recent Global Warming Fabricated by Climatologists
# 1050                                                             PolitiFact Did Hillary Clinton start the Obama birther movement                                    PolitiFact Factchecking Donald Trumps claim Hillary Clinton started Obama birther movement
# 680                            PolitiFact Richard Cordray told Ohio board to give permit to progun group for rally Kucinich says                   PolitiFact Mark Pocan claim Seven years later Scott Walker has not met his jobs promise from first campaign
# 1206                                          PolitiFact State Sen Stephen Martin says Democratic Party created the Ku Klux Klan                       FACT CHECK Did Adolf Hitler Say That Nazis Are Mortal Enemies of the Present Capitalist Economic System
# 1857                                                                   Is Green Party Candidate Jill Stein AntiVaccine Snopescom                                                   Was a Woman Arrested for Making Fur Coats with the Neighbors Cats Snopescom
# 1864                                    FACT CHECK Did Tomi Lahren Say That Victims of Mass Shootings Dont Believe in God Enough                                                   Was a Woman Arrested for Making Fur Coats with the Neighbors Cats Snopescom
# 1490                              FACT CHECK Did Puerto Ricos Teamsters Union Go on Strike During Hurricane Maria Relief Efforts                              PolitiFact Fake news posts blame Puerto Ricos truck drivers for refusing to ship relief supplies
# 1585                          PolitiFact Headlines that say GOP bill makes sexual assault a preexisting condition are misleading                                                                 Did CocaCola Invent the Modern Image of Santa Claus Snopescom
# 3667                                                                                 Bernie Sanders 1972 Essay on Rape Snopescom                                                                Slutwalk Image Repurposed as Womens March Photograph Snopescom
# 493                  FACT CHECK Did Trump Tweet in 2015 That the President Should Be Shot Out of a Cannon if the Dow Joans Tanks                                                                          Russian Billboard Features Trump and Putin Snopescom
# 2856                                                             Did Hillary Clinton Wear Blackface at a Costume Party Snopescom                                                         FACT CHECK Is Jennifer Aniston Starting A Celebrities For Trump Group
# 3168                                        PolitiFact No Roy Moore accuser didnt admit she forged his signature in her yearbook                                                               Tweet Claims Clinton to Drop Out of Presidential Race Snopescom
#